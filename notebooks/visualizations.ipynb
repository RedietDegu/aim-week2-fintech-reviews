# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# Ensure plots show in Jupyter
# %matplotlib inline

# This notebook lives in the project root, so point BASE_DIR there explicitly
BASE_DIR = Path(__file__).resolve().parent
DATA_DIR = BASE_DIR / "data"

csv_path = DATA_DIR / "reviews_with_sentiment_and_themes.csv"
print(f"Loading {csv_path} ...")
df = pd.read_csv(csv_path)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 9
#       6 get_ipython().run_line_magic('matplotlib', 'inline')
#       8 # This notebook lives in the project root, so point BASE_DIR there explicitly
# ----> 9 BASE_DIR = Path(__file__).resolve().parent
#      10 DATA_DIR = BASE_DIR / "data"
#      12 csv_path = DATA_DIR / "reviews_with_sentiment_and_themes.csv"
#
# NameError: name '__file__' is not defined
